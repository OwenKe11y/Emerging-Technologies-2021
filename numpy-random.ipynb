# %% [markdown]
# # The Numpy Random Package
# [Official Documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays
import numpy as np
# Plotting
import matplotlib.pyplot as plt

# %%
# Change default style sheet 
plt.style.use('fivethirtyeight')
# Change the default figure size
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at first 10 items
s[:10]
# Out:
# array([ 0.13023164,  0.05303565, -0.10669146,  0.01412448, -0.06415846,
#         0.0893568 ,  0.09322751, -0.0283822 , -0.02921693, -0.20184034])

# %%
abs(mu - np.mean(s))
# Out:
# 0.002223667748834973

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.001410387740611585

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu)**2 / (2 * sigma**2))
plt.plot(bins, f, linewidth=2)
plt.show()

# %% [markdown]
# # References
# ***
#
# - https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
# - https://stackoverflow.com/questions/36367986/how-to-make-inline-plots-in-jupyter-notebook-larger
# - https://www.python.org/dev/peps/pep-0008/#tabs-or-spaces
# - https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# - https://realpython.com/python-random/

# %% [markdown]
# ***
#
# # End
